# %% [markdown]
# # WeatherPy
#
#
# ### Analysis:
#
# 1. In this scatter plot, it is proven visually any cities furthest away from the equator will have a lower max temperature. Cities closer to the equater will have a greater max temperature. When comparing the linear regression of both northern and southern hemisphere, the relationship between predeiciton and data is strong. The r-value is approximately 0.5.
#
# 2. Plots comparing Latitudes to wind speed, humidity, and cloudiness have no correlation whatsoever. Its data cannot be forcasted by the linear equation. The r-value for those plots are approximately 0.
#
#
# 3. According to the weather forecast pulled on July 24, 2022 the percentage of humidity are greater than 60% in most cities. The wind speed for most cities for that day are forcasted less than 10 mph.
#
# ** Please be advised. Running the notebook will generate a new list of cities. Data will look different than referenced pictures in "output_data" Folder if clicking "run" again. **

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
# (For every coords in lat_longs find the nearest city and append every unique value to cities list)
for coords in lat_lngs:
    city = citipy.nearest_city(coords[0], coords[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
cities
# Out:
# ['pevek',
#  'jamestown',
#  'cape town',
#  'iskateley',
#  'provideniya',
#  'key west',
#  'fairbanks',
#  'ilulissat',
#  'butaritari',
#  'cidreira',
#  'fortuna',
#  'garm',
#  'hermanus',
#  'victoria',
#  'barentsburg',
#  'kaitangata',
#  'bethel',
#  'tiksi',
#  'iqaluit',
#  'mataura',
#  'albany',
#  'vetluga',
#  'thompson',
#  'solnechnyy',
#  'zenzeli',
#  'kuzhener',
#  'qaanaaq',
#  'arraial do cabo',
#  'bambous virieux',
#  'hilo',
#  'presidente medici',
#  'khatanga',
#  'ous',
#  'syracuse',
#  'esperance',
#  'flinders',
#  'puerto leguizamo',
#  'marienburg',
#  'rikitea',
#  'sitka',
#  'punta arenas',
#  'busselton',
#  'avera',
#  'torbay',
#  'illoqqortoormiut',
#  'luwuk',
#  'ponta do sol',
#  'necochea',
#  'ushuaia',
#  'kjopsvik',
#  'taolanaro',
#  'sao joao da barra',
#  'grande-riviere',
#  'den helder',
#  'new norfolk',
#  'khandyga',
#  'artyk',
#  'puerto ayora',
#  'hobart',
#  'yellowknife',
#  'ustyuzhna',
#  'chake chake',
#  'urucui',
#  'codrington',
#  'fulton',
#  'souillac',
#  'vaini',
#  'omsukchan',
#  'athabasca',
#  'chuy',
#  'sabzevar',
#  'belushya guba',
#  'mar del plata',
#  'makakilo city',
#  'bluff',
#  'ostrovnoy',
#  'visnes',
#  'dunedin',
#  'kitami',
#  'syamzha',
#  'nikolskoye',
#  'praia',
#  'isangel',
#  'sechura',
#  'waren',
#  'stonewall',
#  'padang',
#  'strezhevoy',
#  'aklavik',
#  'vagay',
#  'rocha',
#  'mys shmidta',
#  'pisco',
#  'tyukhtet',
#  'bredasdorp',
#  'bengkulu',
#  'avarua',
#  'mapastepec',
#  'hofn',
#  'lyubech',
#  'hualmay',
#  'port lincoln',
#  'biloela',
#  'talas',
#  'severo-kurilsk',
#  'evanston',
#  'attawapiskat',
#  'inta',
#  'nuuk',
#  'marzuq',
#  'mount gambier',
#  'pokhara',
#  'pangkalanbuun',
#  'vryburg',
#  'dikson',
#  'kulhudhuffushi',
#  'peniche',
#  'tilichiki',
#  'faanui',
#  'vila velha',
#  'tombouctou',
#  'tuktoyaktuk',
#  'pangai',
#  'gasa',
#  'kapaa',
#  'georgetown',
#  'concarneau',
#  'dillon',
#  'deh rawud',
#  'cherskiy',
#  'portland',
#  'srednekolymsk',
#  'kattivakkam',
#  'port elizabeth',
#  'ulles',
#  'balimo',
#  'okha',
#  'sterling',
#  'gat',
#  'kawhia',
#  'longyearbyen',
#  'airai',
#  'kavieng',
#  'bilma',
#  'dingle',
#  'kudahuvadhoo',
#  'mountain home',
#  'leningradskiy',
#  'carnarvon',
#  'kodiak',
#  'corn island',
#  'saskylakh',
#  'giraltovce',
#  'bandarbeyla',
#  'palmer',
#  'nago',
#  'dutlwe',
#  'batagay',
#  'naze',
#  'havoysund',
#  'saint-philippe',
#  'sao filipe',
#  'viedma',
#  'qui nhon',
#  'lodwar',
#  'manama',
#  'kupang',
#  'bathsheba',
#  'zhitikara',
#  'saint-francois',
#  'atuona',
#  'samarai',
#  'san quintin',
#  'poum',
#  'amderma',
#  'sentyabrskiy',
#  'yangjiang',
#  'kamenka',
#  'mergui',
#  'balikpapan',
#  'mittagong',
#  'broome',
#  'cayenne',
#  'bud',
#  'sao teotonio',
#  'shelburne',
#  'hithadhoo',
#  'aykhal',
#  'smithers',
#  'faya',
#  'johnstown',
#  'nemuro',
#  'da nang',
#  'bonthe',
#  'east london',
#  'ahipara',
#  'puerto escondido',
#  'eyl',
#  'porto real do colegio',
#  'dzaoudzi',
#  'roebourne',
#  'ginir',
#  'caravelas',
#  'kaeo',
#  'katsuura',
#  'touros',
#  'chokurdakh',
#  'pennadam',
#  'sorvag',
#  'warri',
#  'chicama',
#  'muros',
#  'nizhneyansk',
#  'hamilton',
#  'lebu',
#  'labuhan',
#  'tuatapere',
#  'uyuni',
#  'vestmanna',
#  'talavera',
#  'fort nelson',
#  'chagda',
#  'norman wells',
#  'haysyn',
#  'joshimath',
#  'tignere',
#  'nizwa',
#  'ushumun',
#  'hellin',
#  'lavrentiya',
#  'demba',
#  'karpuninskiy',
#  'maragogi',
#  'soe',
#  'valleyview',
#  'sangar',
#  'ribeira grande',
#  'beringovskiy',
#  'ayolas',
#  'rungata',
#  'ngukurr',
#  'las vegas',
#  'evensk',
#  'batagay-alyta',
#  'ivdel',
#  'benjamin constant',
#  'tartki',
#  'loiza',
#  'sarakhs',
#  'miri',
#  'yablonovo',
#  'maldonado',
#  'boa vista',
#  'kruisfontein',
#  'aswan',
#  'colquechaca',
#  'oum hadjer',
#  'mount isa',
#  'namtsy',
#  'vaitupu',
#  'nizhniy kuranakh',
#  'lixourion',
#  'salalah',
#  'qaqortoq',
#  'aguimes',
#  'coahuayana',
#  'tabuk',
#  'wagar',
#  'port-de-paix',
#  'mushie',
#  'samusu',
#  'tasiilaq',
#  'iquitos',
#  'saint george',
#  'hihifo',
#  'ashqelon',
#  'clyde river',
#  'san patricio',
#  'luderitz',
#  'barrow',
#  'umm kaddadah',
#  'olafsvik',
#  'union',
#  'malyye derbety',
#  'huntsville',
#  'lorengau',
#  'alofi',
#  'vostok',
#  'beira',
#  'deputatskiy',
#  'mahon',
#  'jardim',
#  'southbridge',
#  'jawar',
#  'kavaratti',
#  'perth',
#  'sisimiut',
#  'malinyi',
#  'karamea',
#  'yar-sale',
#  'kazalinsk',
#  'kungurtug',
#  'vila franca do campo',
#  'bairiki',
#  'port alfred',
#  'turan',
#  'henties bay',
#  'castro',
#  'largu',
#  'kuche',
#  'spencer',
#  'geraldton',
#  'sendhwa',
#  'la palma',
#  'vestmannaeyjar',
#  'miracema do tocantins',
#  'shahr-e babak',
#  'moose factory',
#  'alekseyevsk',
#  'ullapool',
#  'ketchikan',
#  'berlevag',
#  'cap malheureux',
#  'narsaq',
#  'bambari',
#  'barranca',
#  'matagami',
#  'sonoita',
#  'wahran',
#  'yelkhovka',
#  'guerrero negro',
#  'innisfail',
#  'ardakan',
#  'port keats',
#  'los altos',
#  'galveston',
#  'mogocha',
#  'margate',
#  'krasnoslobodsk',
#  'varangaon',
#  'staryy nadym',
#  'abu kamal',
#  'coihaique',
#  'montrose',
#  'siguiri',
#  'kieta',
#  'kaduqli',
#  'young',
#  'karkaralinsk',
#  'olutanga',
#  'mayumba',
#  'nouadhibou',
#  'prince rupert',
#  'meulaboh',
#  'tiruvottiyur',
#  'adana',
#  'san jose',
#  'batemans bay',
#  'teknaf',
#  'usinsk',
#  'jiangyou',
#  'hay river',
#  'chany',
#  'gumla',
#  'saint-augustin',
#  'lerwick',
#  'hambantota',
#  'dzialdowo',
#  'lolua',
#  'taua',
#  'kirando',
#  'terenos',
#  'lamar',
#  'harper',
#  'porangatu',
#  'cumana',
#  'grindavik',
#  'saint-louis',
#  'sao miguel do araguaia',
#  'reguengos de monsaraz',
#  'maun',
#  'ruatoria',
#  'dumingag',
#  'valparaiso',
#  'asau',
#  'kalabo',
#  'guanare',
#  'yantongshan',
#  'upernavik',
#  'alice springs',
#  'bubaque',
#  'moussoro',
#  'mahebourg',
#  'itupiranga',
#  'yaan',
#  'logstor',
#  'bonavista',
#  'whitianga',
#  'brae',
#  'bowen',
#  'japura',
#  'qandala',
#  'ambagarh chauki',
#  'nenagh',
#  'luena',
#  'araouane',
#  'san cristobal',
#  'saldanha',
#  'comodoro rivadavia',
#  'porto santo',
#  'bilibino',
#  'san carlos de bariloche',
#  'aripuana',
#  'corning',
#  'kholodnyy',
#  'shingu',
#  'ancud',
#  'lagoa',
#  'axim',
#  'saint-paul',
#  'farafangana',
#  'rakitnoye',
#  'vardo',
#  'jiazi',
#  'sola',
#  'yerbogachen',
#  'dalmatovo',
#  'shadegan',
#  'mareeba',
#  'tahta',
#  'svetlaya',
#  'bolshoy lug',
#  'morges',
#  'petropavlovsk-kamchatskiy',
#  'acarau',
#  'havelock',
#  'xiongzhou',
#  'tsihombe',
#  'hasaki',
#  'laguna',
#  'samalaeulu',
#  'quatre cocos',
#  'lodja',
#  'jiayuguan',
#  'mendota',
#  'zapolyarnyy',
#  'leshukonskoye',
#  'talnakh',
#  'hermosillo',
#  'lata',
#  'rincon',
#  'metro',
#  'virginia beach',
#  'nabire',
#  'komsomolskiy',
#  'saleaula',
#  'coro',
#  'kysyl-syr',
#  'los alamos',
#  'chadan',
#  'maarianhamina',
#  'severodvinsk',
#  'suicheng',
#  'sawakin',
#  'havre-saint-pierre',
#  'hobyo',
#  'sur',
#  'pilao arcado',
#  'wewak',
#  'dzhusaly',
#  'cururupu',
#  'obilnoye',
#  'dudinka',
#  'los llanos de aridane',
#  'abancay',
#  'limbang',
#  'praia da vitoria',
#  'mazagao',
#  'dhidhdhoo',
#  'venice',
#  'tommot',
#  'cape girardeau',
#  'tanacu',
#  'jablanica',
#  'koumac',
#  'honningsvag',
#  'gorontalo',
#  'cabedelo',
#  'abay',
#  'mackenzie',
#  'oxbow',
#  'cabo san lucas',
#  'gigmoto',
#  'filadelfia',
#  'olinda',
#  'hami',
#  'palabuhanratu',
#  'zhuhai',
#  'porlamar',
#  'te anau',
#  'saint-georges',
#  'linxi',
#  'scarborough',
#  'aktau',
#  'umzimvubu',
#  'huron',
#  'camacari',
#  'klaksvik',
#  'roberval',
#  'karratha',
#  'ingham',
#  'mirnyy',
#  'belomorsk',
#  'bratsk',
#  'penzance',
#  'energetik',
#  'khromtau',
#  'tazovskiy',
#  'lermontovka',
#  'xining',
#  'lalmohan',
#  'coquimbo',
#  'taicheng',
#  'funadhoo',
#  'gulshat',
#  'tabory',
#  'saint-pierre',
#  'medford',
#  'karaman',
#  'houma',
#  'dryden',
#  'urubicha',
#  'benguela',
#  'punta gorda',
#  'grand river south east',
#  'nikki',
#  'alta floresta',
#  'vila',
#  'nome',
#  'toliary',
#  'micheweni',
#  'lompoc',
#  'buala',
#  'jiroft',
#  'leninskoye',
#  'tanabe',
#  'jian',
#  'nacala',
#  'cherat',
#  'gornouralskiy',
#  'matamoros',
#  'bukachacha',
#  'tura',
#  'adrar',
#  'barguzin',
#  'aysha',
#  'kawalu',
#  'yulara',
#  'leh',
#  'preobrazheniye',
#  'yarada',
#  'luganville',
#  'nagato',
#  'russell',
#  'skjervoy',
#  'yelizovo',
#  'gotha',
#  'oranjemund',
#  'avanigadda',
#  'parrita',
#  'waingapu',
#  'kibala',
#  'santarem',
#  'raudeberg',
#  'sibolga',
#  'tagusao',
#  'ratnagiri',
#  'roma',
#  'wilmington',
#  'segezha',
#  'voh',
#  'qiongshan',
#  'jeremie',
#  'teya',
#  'porto novo',
#  'wanderlandia',
#  'katherine',
#  'general roca',
#  'gdov',
#  'marcona',
#  'paucartambo',
#  'sungaipenuh',
#  'barroualie',
#  'kastamonu',
#  'sal rei',
#  'marsa matruh',
#  'portlethen',
#  'mocuba',
#  'hvolsvollur',
#  'bolobo',
#  'illapel',
#  'maine-soroa',
#  'tiznit',
#  'zabol',
#  'yazoo city',
#  'merauke',
#  'constitucion',
#  'beyneu',
#  'saryg-sep',
#  'mrirt',
#  'medea',
#  'watsa',
#  'tautira',
#  'kamenskoye',
#  'kismayo',
#  'druzhba',
#  'dan khun thot',
#  'saint-marc-des-carrieres',
#  'fergus falls',
#  'sandakan',
#  'ostersund',
#  'westport',
#  'mossendjo',
#  'kununurra',
#  'great yarmouth',
#  'acapulco',
#  'barentu']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# URL Configurations

baseURL = 'https://api.openweathermap.org/data/2.5/weather?'
units = 'imperial'
queryURL = f"{baseURL}appid={weather_api_key}&units={units}&q="

# Test response
#weather_response = requests.get(queryURL + 'Vancouver').json()
#weather_response

# %%
# Create an empty response list to store responses and lists
city_name = []
lat = []
long = []
maxTemp = []
humidity = []
cloud = []
wind_speed = []
country = []
date = []
print("Beginning Data Retrieval:\n"
     "-----------------------------------")

# Set counters
index_counter = 0
set_counter = 1

# Make a request for each city using a for loop
for i, city in enumerate (cities, start = 1):
    try:
        response = requests.get(queryURL + city).json()
        city_name.append(response['name'])
        lat.append(response["coord"]["lat"])
        long.append(response["coord"]["lon"])
        maxTemp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloud.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
        else:
            index_counter = index_counter + 1
        print(f"Processing Record {index_counter} of Set {set_counter} | {city}")
        
    except(KeyError, IndexError):
        
        print("City not found. Skipping...")
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval:
# -----------------------------------
# Processing Record 1 of Set 1 | pevek
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | iskateley
# Processing Record 5 of Set 1 | provideniya
# Processing Record 6 of Set 1 | key west
# Processing Record 7 of Set 1 | fairbanks
# Processing Record 8 of Set 1 | ilulissat
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | cidreira
# Processing Record 11 of Set 1 | fortuna
# City not found. Skipping...
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | victoria
# City not found. Skipping...
# Processing Record 14 of Set 1 | kaitangata
# Processing Record 15 of Set 1 | bethel
# Processing Record 16 of Set 1 | tiksi
# Processing Record 17 of Set 1 | iqaluit
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | vetluga
# Processing Record 21 of Set 1 | thompson
# Processing Record 22 of Set 1 | solnechnyy
# Processing Record 23 of Set 1 | zenzeli
# Processing Record 24 of Set 1 | kuzhener
# Processing Record 25 of Set 1 | qaanaaq
# Processing Record 26 of Set 1 | arraial do cabo
# Processing Record 27 of Set 1 | bambous virieux
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | presidente medici
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | ous
# Processing Record 32 of Set 1 | syracuse
# Processing Record 33 of Set 1 | esperance
# Processing Record 34 of Set 1 | flinders
# Processing Record 35 of Set 1 | puerto leguizamo
# Processing Record 36 of Set 1 | marienburg
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | sitka
# Processing Record 39 of Set 1 | punta arenas
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | avera
# Processing Record 42 of Set 1 | torbay
# City not found. Skipping...
# Processing Record 43 of Set 1 | luwuk
# Processing Record 44 of Set 1 | ponta do sol
# Processing Record 45 of Set 1 | necochea
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | kjopsvik
# City not found. Skipping...
# Processing Record 48 of Set 1 | sao joao da barra
# City not found. Skipping...
# Processing Record 49 of Set 1 | den helder
# Processing Record 50 of Set 1 | new norfolk
# Processing Record 0 of Set 2 | khandyga
# City not found. Skipping...
# Processing Record 1 of Set 2 | puerto ayora
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | yellowknife
# Processing Record 43 of Set 4 | muros
# City not found. Skipping...
# Processing Record 44 of Set 4 | hamilton
# Processing Record 45 of Set 4 | lebu
# Processing Record 46 of Set 4 | labuhan
# Processing Record 47 of Set 4 | tuatapere
# Processing Record 48 of Set 4 | uyuni
# Processing Record 49 of Set 4 | vestmanna
# Processing Record 50 of Set 4 | talavera
# Processing Record 0 of Set 5 | fort nelson
# City not found. Skipping...
# Processing Record 1 of Set 5 | norman wells
# Processing Record 2 of Set 5 | haysyn
# Processing Record 3 of Set 5 | joshimath
# Processing Record 4 of Set 5 | tignere
# Processing Record 5 of Set 5 | nizwa
# Processing Record 6 of Set 5 | ushumun
# Processing Record 7 of Set 5 | hellin
# Processing Record 8 of Set 5 | lavrentiya
# Processing Record 9 of Set 5 | demba
# City not found. Skipping...
# Processing Record 10 of Set 5 | maragogi
# Processing Record 11 of Set 5 | soe
# Processing Record 12 of Set 5 | valleyview
# Processing Record 13 of Set 5 | sangar
# Processing Record 14 of Set 5 | ribeira grande
# Processing Record 15 of Set 5 | beringovskiy
# Processing Record 16 of Set 5 | ayolas
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 17 of Set 5 | las vegas
# Processing Record 18 of Set 5 | evensk
# Processing Record 19 of Set 5 | batagay-alyta
# Processing Record 20 of Set 5 | ivdel
# Processing Record 21 of Set 5 | benjamin constant
# City not found. Skipping...
# Processing Record 22 of Set 5 | loiza
# Processing Record 23 of Set 5 | sarakhs
# Processing Record 24 of Set 5 | miri
# Processing Record 25 of Set 5 | yablonovo
# Processing Record 26 of Set 5 | maldonado
# Processing Record 27 of Set 5 | boa vista
# Processing Record 28 of Set 5 | kruisfontein
# Processing Record 29 of Set 5 | aswan
# Processing Record 30 of Set 5 | colquechaca
# Processing Record 31 of Set 5 | oum hadjer
# Processing Record 32 of Set 5 | mount isa
# Processing Record 33 of Set 5 | namtsy
# City not found. Skipping...
# Processing Record 34 of Set 5 | nizhniy kuranakh
# Processing Record 35 of Set 5 | lixourion
# Processing Record 36 of Set 5 | salalah
# Processing Record 37 of Set 5 | qaqortoq
# Processing Record 38 of Set 5 | aguimes
# Processing Record 39 of Set 5 | coahuayana
# Processing Record 40 of Set 5 | tabuk
# Processing Record 41 of Set 5 | wagar
# City not found. Skipping...
# Processing Record 42 of Set 5 | mushie
# City not found. Skipping...
# Processing Record 43 of Set 5 | tasiilaq
# Processing Record 44 of Set 5 | iquitos
# Processing Record 45 of Set 5 | saint george
# City not found. Skipping...
# Processing Record 46 of Set 5 | ashqelon
# Processing Record 47 of Set 5 | clyde river
# Processing Record 48 of Set 5 | san patricio
# Processing Record 49 of Set 5 | luderitz
# Processing Record 50 of Set 5 | barrow
# Processing Record 0 of Set 6 | umm kaddadah
# Processing Record 1 of Set 6 | olafsvik
# Processing Record 2 of Set 6 | union
# Processing Record 3 of Set 6 | malyye derbety
# Processing Record 4 of Set 6 | huntsville
# Processing Record 5 of Set 6 | lorengau
# Processing Record 6 of Set 6 | alofi
# Processing Record 7 of Set 6 | vostok
# Processing Record 8 of Set 6 | beira
# Processing Record 9 of Set 6 | deputatskiy
# Processing Record 10 of Set 6 | mahon
# Processing Record 11 of Set 6 | jardim
# Processing Record 12 of Set 6 | southbridge
# Processing Record 13 of Set 6 | jawar
# Processing Record 14 of Set 6 | kavaratti
# Processing Record 15 of Set 6 | perth
# Processing Record 16 of Set 6 | sisimiut
# Processing Record 17 of Set 6 | malinyi
# City not found. Skipping...
# Processing Record 18 of Set 6 | yar-sale
# City not found. Skipping...
# Processing Record 19 of Set 6 | kungurtug
# Processing Record 20 of Set 6 | vila franca do campo
# Processing Record 21 of Set 6 | bairiki
# Processing Record 22 of Set 6 | port alfred
# Processing Record 23 of Set 6 | turan
# Processing Record 24 of Set 6 | henties bay
# Processing Record 25 of Set 6 | castro
# Processing Record 26 of Set 6 | largu
# City not found. Skipping...
# Processing Record 27 of Set 6 | spencer
# Processing Record 28 of Set 6 | geraldton
# Processing Record 29 of Set 6 | sendhwa
# Processing Record 30 of Set 6 | la palma
# Processing Record 31 of Set 6 | vestmannaeyjar
# Processing Record 32 of Set 6 | miracema do tocantins
# Processing Record 33 of Set 6 | shahr-e babak
# Processing Record 34 of Set 6 | moose factory
# Processing Record 35 of Set 6 | alekseyevsk
# Processing Record 36 of Set 6 | ullapool
# Processing Record 37 of Set 6 | ketchikan
# Processing Record 38 of Set 6 | berlevag
# Processing Record 39 of Set 6 | cap malheureux
# Processing Record 40 of Set 6 | narsaq
# Processing Record 41 of Set 6 | bambari
# Processing Record 42 of Set 6 | barranca
# Processing Record 43 of Set 6 | matagami
# Processing Record 44 of Set 6 | sonoita
# City not found. Skipping...
# Processing Record 45 of Set 6 | yelkhovka
# Processing Record 46 of Set 6 | guerrero negro
# Processing Record 47 of Set 6 | innisfail
# Processing Record 48 of Set 6 | ardakan
# Processing Record 49 of Set 6 | port keats
# Processing Record 50 of Set 6 | los altos
# Processing Record 0 of Set 7 | galveston
# Processing Record 1 of Set 7 | mogocha
# Processing Record 2 of Set 7 | margate
# Processing Record 3 of Set 7 | krasnoslobodsk
# Processing Record 4 of Set 7 | varangaon
# Processing Record 5 of Set 7 | staryy nadym
# Processing Record 6 of Set 7 | abu kamal
# Processing Record 7 of Set 7 | coihaique
# Processing Record 8 of Set 7 | montrose
# Processing Record 9 of Set 7 | siguiri
# Processing Record 10 of Set 7 | kieta
# Processing Record 11 of Set 7 | kaduqli
# Processing Record 12 of Set 7 | young
# City not found. Skipping...
# Processing Record 13 of Set 7 | olutanga
# Processing Record 14 of Set 7 | mayumba
# Processing Record 15 of Set 7 | nouadhibou
# Processing Record 16 of Set 7 | prince rupert
# Processing Record 17 of Set 7 | meulaboh
# City not found. Skipping...
# Processing Record 18 of Set 7 | adana
# Processing Record 19 of Set 7 | san jose
# Processing Record 20 of Set 7 | batemans bay
# Processing Record 21 of Set 7 | teknaf
# Processing Record 22 of Set 7 | usinsk
# Processing Record 23 of Set 7 | jiangyou
# Processing Record 24 of Set 7 | hay river
# Processing Record 25 of Set 7 | chany
# Processing Record 26 of Set 7 | gumla
# Processing Record 27 of Set 7 | saint-augustin
# Processing Record 16 of Set 10 | energetik
# Processing Record 17 of Set 10 | khromtau
# Processing Record 18 of Set 10 | tazovskiy
# Processing Record 19 of Set 10 | lermontovka
# Processing Record 20 of Set 10 | xining
# Processing Record 21 of Set 10 | lalmohan
# Processing Record 22 of Set 10 | coquimbo
# Processing Record 23 of Set 10 | taicheng
# Processing Record 24 of Set 10 | funadhoo
# City not found. Skipping...
# Processing Record 25 of Set 10 | tabory
# Processing Record 26 of Set 10 | saint-pierre
# Processing Record 27 of Set 10 | medford
# Processing Record 28 of Set 10 | karaman
# Processing Record 29 of Set 10 | houma
# Processing Record 30 of Set 10 | dryden
# Processing Record 31 of Set 10 | urubicha
# Processing Record 32 of Set 10 | benguela
# Processing Record 33 of Set 10 | punta gorda
# City not found. Skipping...
# Processing Record 34 of Set 10 | nikki
# Processing Record 35 of Set 10 | alta floresta
# Processing Record 36 of Set 10 | vila
# Processing Record 37 of Set 10 | nome
# City not found. Skipping...
# Processing Record 38 of Set 10 | micheweni
# Processing Record 39 of Set 10 | lompoc
# Processing Record 40 of Set 10 | buala
# City not found. Skipping...
# Processing Record 41 of Set 10 | leninskoye
# Processing Record 42 of Set 10 | tanabe
# Processing Record 43 of Set 10 | jian
# Processing Record 44 of Set 10 | nacala
# Processing Record 45 of Set 10 | cherat
# City not found. Skipping...
# Processing Record 46 of Set 10 | matamoros
# Processing Record 47 of Set 10 | bukachacha
# Processing Record 48 of Set 10 | tura
# Processing Record 49 of Set 10 | adrar
# Processing Record 50 of Set 10 | barguzin
# Processing Record 0 of Set 11 | aysha
# Processing Record 1 of Set 11 | kawalu
# Processing Record 2 of Set 11 | yulara
# Processing Record 3 of Set 11 | leh
# Processing Record 4 of Set 11 | preobrazheniye
# Processing Record 5 of Set 11 | yarada
# Processing Record 6 of Set 11 | luganville
# Processing Record 7 of Set 11 | nagato
# Processing Record 8 of Set 11 | russell
# Processing Record 9 of Set 11 | skjervoy
# Processing Record 10 of Set 11 | yelizovo
# Processing Record 11 of Set 11 | gotha
# Processing Record 12 of Set 11 | oranjemund
# Processing Record 13 of Set 11 | avanigadda
# Processing Record 14 of Set 11 | parrita
# Processing Record 15 of Set 11 | waingapu
# Processing Record 16 of Set 11 | kibala
# Processing Record 17 of Set 11 | santarem
# Processing Record 18 of Set 11 | raudeberg
# Processing Record 19 of Set 11 | sibolga
# Processing Record 20 of Set 11 | tagusao
# Processing Record 21 of Set 11 | ratnagiri
# Processing Record 22 of Set 11 | roma
# Processing Record 23 of Set 11 | wilmington
# Processing Record 24 of Set 11 | segezha
# Processing Record 25 of Set 11 | voh
# Processing Record 26 of Set 11 | qiongshan
# Processing Record 27 of Set 11 | jeremie
# Processing Record 28 of Set 11 | teya
# Processing Record 29 of Set 11 | porto novo
# City not found. Skipping...
# Processing Record 30 of Set 11 | katherine
# Processing Record 31 of Set 11 | general roca
# Processing Record 32 of Set 11 | gdov
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of Set 11 | sungaipenuh
# City not found. Skipping...
# Processing Record 34 of Set 11 | kastamonu
# Processing Record 35 of Set 11 | sal rei
# Processing Record 36 of Set 11 | marsa matruh
# Processing Record 37 of Set 11 | portlethen
# Processing Record 38 of Set 11 | mocuba
# Processing Record 39 of Set 11 | hvolsvollur
# Processing Record 40 of Set 11 | bolobo
# Processing Record 41 of Set 11 | illapel
# Processing Record 42 of Set 11 | maine-soroa
# Processing Record 43 of Set 11 | tiznit
# Processing Record 44 of Set 11 | zabol
# Processing Record 45 of Set 11 | yazoo city
# Processing Record 46 of Set 11 | merauke
# Processing Record 47 of Set 11 | constitucion
# Processing Record 48 of Set 11 | beyneu
# Processing Record 49 of Set 11 | saryg-sep
# City not found. Skipping...
# Processing Record 50 of Set 11 | medea
# Processing Record 0 of Set 12 | watsa
# Processing Record 1 of Set 12 | tautira
# City not found. Skipping...
# Processing Record 2 of Set 12 | kismayo
# Processing Record 3 of Set 12 | druzhba
# Processing Record 4 of Set 12 | dan khun thot
# Processing Record 5 of Set 12 | saint-marc-des-carrieres
# Processing Record 6 of Set 12 | fergus falls
# Processing Record 7 of Set 12 | sandakan
# Processing Record 8 of Set 12 | ostersund
# Processing Record 9 of Set 12 | westport
# Processing Record 10 of Set 12 | mossendjo
# Processing Record 11 of Set 12 | kununurra
# Processing Record 12 of Set 12 | great yarmouth
# Processing Record 13 of Set 12 | acapulco
# Processing Record 14 of Set 12 | barentu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Build DF with Lat and Long and the max temp, humidity, wind speed, country, date
weatherDF = pd.DataFrame({
    "City" : city_name,
    "Lat" : lat, 
    "Long" : long, 
    "Max Temp (F)" : maxTemp, 
    "Humidity" : humidity, 
    "Cloudiness" : cloud, 
    "Wind Speed" : wind_speed, 
    "Country" : country, 
    "Date" : date
})
weatherDF

# Export into a csv
weatherDF.to_csv("../output_data/cities.csv")

# Use .describe to get summary stats
summary_weatherDF = weatherDF.describe()
summary_weatherDF
# Out:
#                    City      Lat      Long  Max Temp (F)  Humidity  \
# 0                 Pevek  69.7008  170.3133         36.10        88
# 1             Jamestown  42.0970  -79.2353         84.94        71
# 2             Cape Town -33.9258   18.4232         59.38        69
# 3             Iskateley  67.6803   53.1512         51.31        75
# 4           Provideniya  64.3833 -173.3000         42.53        87
# ..                  ...      ...       ...           ...       ...
# 570           Mossendjo  -2.9506   12.7261         76.41        63
# 571           Kununurra -15.7667  128.7333         49.98        81
# 572      Great Yarmouth  52.6083    1.7305         82.65        36
# 573  Acapulco de Juárez  16.8634  -99.8901         87.62        66
# 574             Barentu  15.1139   37.5928         68.83        82
#
#      Cloudiness  Wind Speed Country        Date
# 0            58        0.85      RU  1658685924
# 1            75        9.22      US  1658685925
# 2             0       11.99      ZA  1658685902
# 3           100        9.19      RU  1658685926
# 4           100        5.12      RU  1658685434
# ..          ...         ...     ...         ...
# 570          95        2.48      CG  1658686111
# 571           4        0.00      AU  1658686111
# 572          23       18.52      GB  1658686111
# 573          40        6.91      MX  1658686112
# 574         100        4.05      ER  1658686112
#
# [575 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
humidity100_index = weatherDF[(weatherDF['Humidity'] > 100)]
humidity100_index

# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

#clean_city_data = weatherDF.drop(humidity100_index, inplace=False)
#clean_city_data.head()
# Out:
# Empty DataFrame
# Columns: [City, Lat, Long, Max Temp (F), Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create Latitude vs. Max Temperature Plot
tempScatter = plt.scatter(weatherDF["Lat"], weatherDF["Max Temp (F)"], facecolor="lightblue", edgecolor = "black")
plt.title("Max Temperature (F) vs. City Latitude (07/24/22)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(linestyle='-')
plt.savefig("../output_data/lat_temp.png")

print("Max Temperature (F) vs. City Latitude: The further away cities are from the equator, the max temperature decreases. "
     "Cities closer to the equator display higher max temperatures.")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create Latitude vs. Humidity Plot
humidityScatter = plt.scatter(weatherDF["Lat"], weatherDF["Humidity"], facecolor="lightblue", edgecolor = "black")
plt.title("Humidity (%) vs City Latitude (07/24/22)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(linestyle='-')
plt.savefig("../output_data/lat_humidity.png")

print("Humidity (%) vs Latitude: At this time of year, most countries are 60% or greater in humidity.")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create Latitude vs. Cloudiness
cloudScatter = plt.scatter(weatherDF["Lat"], weatherDF["Cloudiness"], facecolor="lightblue", edgecolor = "black")
plt.title("Cloudiness vs. City Latitude (07/24/22)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(linestyle='-')
plt.savefig("../output_data/lat_cloud.png")

print("Cloudiness vs. City Latitude: A majority of cities north of the equator are experiencing 60% cloudiness or higher.")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create Latitude vs. Wind Speed
windScatter = plt.scatter(weatherDF["Lat"], weatherDF["Wind Speed"], facecolor="lightblue", edgecolor = "black")
plt.title("Wind Speed (mph) vs City Latitude (07/24/22)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(linestyle='-')
plt.savefig("../output_data/lat_windspeed.png")

print("Wind Speed vs Latitude: At this time of year, a majority of cities are experiencing wind speed 10 mph or less.")

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Seperate DF into North and South Hempispheres lats

north_hemX = weatherDF.loc[(weatherDF['Lat'] >= 0)]
south_hemX = weatherDF.loc[(weatherDF['Lat'] < 0)]

# %%
# Set x and y axis for North Hemp Lat v Max Temp
NtempLatX = north_hemX['Lat']
NtempY = north_hemX['Max Temp (F)']

# Calculate and plot linear regress for North Hemp. v Max Temp
(Ntemp_slope, Ntemp_intercept, Ntemp_rvalue, pvalue, stderr) = linregress(NtempLatX, NtempY)
Ntemp_regress_values = NtempLatX * Ntemp_slope + Ntemp_intercept
Ntemp_line_eq = "y = " + str(round(Ntemp_slope,2)) + "x + " + str(round(Ntemp_intercept,2))

plt.scatter(NtempLatX, NtempY)
plt.plot(NtempLatX,Ntemp_regress_values,"r-")
plt.annotate(Ntemp_line_eq,(0,50),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("Northern Hempisphere vs. Max Temperature (F) (07/24/22)")

print(f"The r-value is: {Ntemp_rvalue**2:.2f}")
plt.savefig("../output_data/north_temp.png")
# Out:
# The r-value is: 0.46

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Set x and y axis for South Hemp Lat v Max Temp
StempLatX = south_hemX['Lat']
StempY = south_hemX['Max Temp (F)']

# Calculate and plot linear regress for North Hemp. v Max Temp
(Stemp_slope, Stemp_intercept, Stemp_rvalue, pvalue, stderr) = linregress(StempLatX, StempY)
Stemp_regress_values = StempLatX * Stemp_slope + Stemp_intercept
Stemp_line_eq = "y = " + str(round(Stemp_slope,2)) + "x + " + str(round(Stemp_intercept,2))

plt.scatter(StempLatX, StempY)
plt.plot(StempLatX,Stemp_regress_values,"r-")
plt.annotate(Stemp_line_eq,(-50,80),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("Southern Hemisphere vs. Max Temperature (F) (07/24/22)")

print(f"The r-value is: {Stemp_rvalue**2:.2f}")
print("North Hemisphere vs Max Temp has a strong negative correlation. Cities north of the latitude, display "
      "decreasing max temperatures. The data and r-value confirms the prediction made by the linear regression line.\n"
     "South Hemisphere vs. Max Temp has a strong positive correlation. Cities closer to the latitude have higher max "
     "temperatures. Data confirms the linear regression line, as cities get closer to the equator,, max temperature is "
     "increased.")


plt.savefig("../output_data/south_temp.png")
# Out:
# The r-value is: 0.61

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Set x and y axis for North Hemp Lat v Humidity
NhumidLatX = north_hemX['Lat']
NhumidY = north_hemX['Humidity']

# Calculate and plot linear regress for North Hemp. v Max Temp
(Nhumid_slope, Nhumid_intercept, Nhumid_rvalue, pvalue, stderr) = linregress(NhumidLatX, NhumidY)
Nhumid_regress_values = NhumidLatX * Nhumid_slope + Nhumid_intercept
Nhumid_line_eq = "y = " + str(round(Nhumid_slope,2)) + "x + " + str(round(Nhumid_intercept,2))

plt.scatter(NhumidLatX, NhumidY)
plt.plot(NhumidLatX,Nhumid_regress_values,"r-")
plt.annotate(Nhumid_line_eq,(50,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Northern Hempisphere vs. Humidity (%) (07/24/22)")

print(f"The r-value is: {Nhumid_rvalue**2:.2f}")
plt.savefig("../output_data/north_humidity.png")
# Out:
# The r-value is: 0.02

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Set x and y axis for Sorth Hemp Lat v Humidity
ShumidLatX = south_hemX['Lat']
ShumidY = south_hemX['Humidity']

# Calculate and plot linear regress for North Hemp. v Max Temp
(Shumid_slope, Shumid_intercept, Shumid_rvalue, pvalue, stderr) = linregress(ShumidLatX, ShumidY)
Shumid_regress_values = ShumidLatX * Shumid_slope + Shumid_intercept
Shumid_line_eq = "y = " + str(round(Shumid_slope,2)) + "x + " + str(round(Shumid_intercept,2))

plt.scatter(ShumidLatX, ShumidY)
plt.plot(ShumidLatX,Shumid_regress_values,"r-")
plt.annotate(Shumid_line_eq,(-55,50),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Southern Hempisphere vs. Humidity (%) (07/24/22)")

print(f"The r-value is: {Shumid_rvalue**2:.2f}")

print("Both northern and southern vs humidity plots have no correlation. The linear regression line does not predict "
     "humidity forecast.")

plt.savefig("../output_data/south_humidity.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_36868\3077916443.py in <module>
#       1 # Set x and y axis for Sorth Hemp Lat v Humidity
# ----> 2 ShumidLatX = south_hemX['Lat']
#       3 ShumidY = south_hemX['Humidity']
#       4
#       5 # Calculate and plot linear regress for North Hemp. v Max Temp
#
# NameError: name 'south_hemX' is not defined

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Set x and y axis for North Hemp Lat v Cloudiness (%)
NcloudLatX = north_hemX['Lat']
NcloudY = north_hemX['Cloudiness']

# Calculate and plot linear regress for North Hemp. v Max Temp
(Ncloud_slope, Ncloud_intercept, Ncloud_rvalue, pvalue, stderr) = linregress(NcloudLatX, NcloudY)
Ncloud_regress_values = NcloudLatX * Ncloud_slope + Ncloud_intercept
Ncloud_line_eq = "y = " + str(round(Ncloud_slope,2)) + "x + " + str(round(Ncloud_intercept,2))

plt.scatter(NcloudLatX, NcloudY)
plt.plot(NcloudLatX,Ncloud_regress_values,"r-")
plt.annotate(Ncloud_line_eq,(0,50),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Northern Hempisphere vs. Cloudiness (%) (07/24/22)")

print(f"The r-value is: {Ncloud_rvalue**2:.2f}")
plt.savefig("../output_data/north_cloudiness.png")
# Out:
# The r-value is: 0.01

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Set x and y axis for South Hemp Lat v Cloudiness (%)
ScloudLatX = south_hemX['Lat']
ScloudY = south_hemX['Cloudiness']

# Calculate and plot linear regress for North Hemp. v Max Temp
(Scloud_slope, Scloud_intercept, Scloud_rvalue, pvalue, stderr) = linregress(ScloudLatX, ScloudY)
Scloud_regress_values = ScloudLatX * Scloud_slope + Scloud_intercept
Scloud_line_eq = "y = " + str(round(Scloud_slope,2)) + "x + " + str(round(Scloud_intercept,2))

plt.scatter(ScloudLatX, ScloudY)
plt.plot(ScloudLatX,Scloud_regress_values,"r-")
plt.annotate(Scloud_line_eq,(-50,50),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Southern Hempisphere vs. Cloudiness (%) (07/24/22)")

print(f"The r-value is: {Scloud_rvalue**2:.2f}")

print("Both northern and southern hemisphere vs cloudiness have no correlation. r-value = 0. The linear regression line "
     "does not predict the forecast for chance of cloudiness in this case.")
plt.savefig("../output_data/south_cloudiness.png")
# Out:
# The r-value is: 0.00

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Set x and y axis for North Hemp Lat v Max Temp
NwindLatX = north_hemX['Lat']
NwindY = north_hemX['Wind Speed']

# Calculate and plot linear regress for North Hemp. v Max Temp
(Nwind_slope, Nwind_intercept, Nwind_rvalue, pvalue, stderr) = linregress(NwindLatX, NwindY)
Nwind_regress_values = NwindLatX * Nwind_slope + Nwind_intercept
Nwind_line_eq = "y = " + str(round(Nwind_slope,2)) + "x + " + str(round(Nwind_intercept,2))

plt.scatter(NwindLatX, NwindY)
plt.plot(NwindLatX,Nwind_regress_values,"r-")
plt.annotate(Nwind_line_eq,(0,25),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Northern Hempisphere vs. Wind Speed (mph) (07/24/22)")

print(f"The r-value is: {Nwind_rvalue**2:.2f}")
plt.savefig("../output_data/north_windspeed.png")
# Out:
# The r-value is: 0.00

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Set x and y axis for North Hemp Lat v Max Temp
SwindLatX = south_hemX['Lat']
SwindY = south_hemX['Wind Speed']

# Calculate and plot linear regress for North Hemp. v Max Temp
(Swind_slope, Swind_intercept, Swind_rvalue, pvalue, stderr) = linregress(SwindLatX, SwindY)
Swind_regress_values = SwindLatX * Swind_slope + Swind_intercept
Swind_line_eq = "y = " + str(round(Swind_slope,2)) + "x + " + str(round(Swind_intercept,2))

plt.scatter(SwindLatX, SwindY)
plt.plot(SwindLatX,Swind_regress_values,"r-")
plt.annotate(Swind_line_eq,(-55,15),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Southern Hempisphere vs. Wind Speed (mph) (07/24/22)")

print(f"The r-value is: {Swind_rvalue**2:.2f}")

print("Both northern and southern hemisphere vs wind speed have no correlation. r-value = 0. The linear regression line "
     "does not predict the forecast for wind speed in this scenario.")

plt.savefig("../output_data/south_windspeed.png")
# Out:
# The r-value is: 0.01
